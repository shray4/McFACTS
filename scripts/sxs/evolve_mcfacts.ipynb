# %%
# ===========================================
#     OUTDATED FILE - NO NEED FOR USE
# ===========================================

# %%
import juliacall
import numpy as np
import fit_modeler
import mcfacts.external.sxs.surrogate as surrogate
import pandas as pd
import time, os
import surrogate
from astropy import constants as const
import matplotlib.pyplot as plt

from mcfacts.vis import plotting
from mcfacts.vis import styles

np.set_printoptions(legacy='1.13')

### Should work for everyone ###
# Current directory
#HERE=$(shell pwd)
#/Users/sray/Documents/1Saavik_Barry/test_mcfacts
#os.getcwd()
HERE = '/Users/sray/Documents/1Saavik_Barry/test_mcfacts'

#### Scripts ####
# Change final number of zeros depending on how many galaxies are initialized (example: 1 galaxy - 'runs/gal0'; 10 galaxies - 'runs/gal00'; 100 galaxies -'runs/gal000')
MCFACTS_RUNS_GAL = HERE + '/runs/gal000'
MCFACTS_RUNS = HERE + '/runs'

# Code that will match the number of objects and galaxies being run without the user having to change it manually
dir_path = (MCFACTS_RUNS_GAL)
objects = int((len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))]) - 2)/3)
galaxies = len(next(os.walk(MCFACTS_RUNS))[1])

# Change value of n - zfill(n) - to match the order of magnitude of number of galaxies being run
gal = [str(i).zfill(3) for i in range(galaxies)]
obj = [str(i) for i in range(objects)]
runs = [[] for _ in range(len(gal))]

for i in range(len(gal)):
    for j in range(len(obj)):
        temp = '/Users/sray/Documents/1Saavik_Barry/test_mcfacts/runs/gal' + gal[i] + '/output_bh_binary_' + obj[j] + '.dat'
        runs[i].append(temp)

#with open("Output.txt", "w") as text_file:
    #text_file.write(str(gal))
    
# Setting up surrogate model
surrogate = fit_modeler.GPRFitters.read_from_file(f"surrogate.joblib")

# Creating a hard coded binary seperation to speed up the surrogate model 
# ========= NEEDS CHANGES: change hard set binary value to change depending on the mass ratio ============
def new_bin_sep(freq, i):
    active_bin = pd.read_csv(i, delimiter=' ', header = 0)
    mass_1 = active_bin['mass_1']
    mass_2 = active_bin['mass_2']
    #print(mass_1)
    G = const.G.value
    M_dot = 2e30
    grav_freq = freq
    
    #print('mass_1: ', active_bin['mass_1'])
    #print('grav_freq: ', active_bin['gw_freq'])
    
    a_bin = ((G * (mass_1 + mass_2) * M_dot * np.pi**2) / grav_freq**2) ** (1/3)
    #a_bin = ((G * (mass_1 + mass_2) * M_dot) / (16 * grav_freq**2 * np.pi**2))**1/3
    a_bin_rg = a_bin / 1.5e11
    return a_bin_rg

total_mass_final = []
total_spin_final = []
total_velocity_final = []
total_radius_final = []
total_gen_final = []
total_boa_final = []

num_of_obj_mergers = []
num_of_gal_mergers = []

sur_time_start = time.time()

# Starting loops to determine binary merger events 
# Beginning with a new galaxy and iterating through each of the timesteps within the galaxy
for i in range(len(gal)):
    merger_counter_gal = []
    print('===================================   NEW GALAXY   =================================')
    for j in range(len(obj)):
        if j == 0:
            continue
        merger_counter_obj = []
        total_start_mass1 = []
        total_start_mass2 = []
        total_start_spin1 = []
        total_start_spin2 = []
        
        #The following logic systems use the current binary as the base for checks
        active_bin = pd.read_csv(runs[i][j], delimiter=' ', header = 0)
        print('----------------     NEW TIMESTEP     ----------------')
        mass_final = []
        spin_final = []
        velocity_final = []
        radius_final = []
        gen_final = []
        boa_final = []
        
        starting_mass1 = []
        starting_mass2 = []
        starting_spin1 = []
        starting_spin2 = []
        
        # This checks if the current timestep is empty
        if active_bin.empty:
            print('Galaxy ', gal[i], ' and run ', obj[j])
            print('file is empty. Checking for previous binaries and moving onto next system')
            act_bin_prev = pd.read_csv(runs[i][j-1], delimiter=' ', header = 0)
            
            bh_prev = act_bin_prev['id_num']
            bh = active_bin['id_num']
            
            #This loop checks if there are any previously generated binaries
            # If there are any previously merged binaries, then this must mean those binaries have merged
            #  since the current timestep is empty.
            if bh_prev.empty:
                print('no previously merged binaries')
            else:
                for k, values in enumerate(bh_prev):
                    print('binary ', values, ' has merged...beginning surrogate model')
                    
                    
                    #merger_counter_obj.append(obj[j])
                    mass_1 = act_bin_prev['mass_1'][k]
                    mass_2 = act_bin_prev['mass_2'][k]
                    spin_1_mag = act_bin_prev['spin_1'][k]
                    spin_2_mag = act_bin_prev['spin_2'][k]
                    spin_angle_1 = act_bin_prev['spin_angle_1'][k]
                    spin_angle_2 = act_bin_prev['spin_angle_2'][k]
                    radius = act_bin_prev['bin_orb_a'][k]
                    gen_1 = act_bin_prev['gen_1'][k]
                    gen_2 = act_bin_prev['gen_2'][k]
                    phi_12 = spin_angle_2 - spin_angle_1
                    # This should be in units of mass_1 + mass_2
                    bin_sep = 1000
                    bin_inc = [0, 0, 1]
                    bin_phase = 0
                    # These next three are used to correct the remnant velocity;
                    # If they are None, no correction is applied.
                    bin_orb_a = None
                    mass_SMBH = None
                    spin_SMBH = None
                    
                    #print('surrogate test: ', mass_1, mass_2, spin_1_mag, spin_2_mag, spin_angle_1, spin_angle_2, phi_12)
                    
                    surrogate = fit_modeler.GPRFitters.read_from_file(f"surrogate.joblib")

                    start = time.time()
                    M_f, spin_f, v_f = surrogate.evolve_binary(
                        mass_1,
                        mass_2,
                        spin_1_mag,
                        spin_2_mag,
                        spin_angle_1,
                        spin_angle_2,
                        phi_12,
                        bin_sep,
                        bin_inc,
                        bin_phase,
                        bin_orb_a,
                        mass_SMBH,
                        spin_SMBH,
                        surrogate,
                        verbose=True,
                    )
                    end = time.time()
                    
                    run_time = end - start

                    mass_final.append(M_f)
                    spin_final.append(spin_f)
                    velocity_final.append(v_f)
                    radius_final.append(radius)
                    bin_orb_a = act_bin_prev['bin_orb_a'][k]
                    boa_final.append(bin_orb_a)
                    
                    #print('x_final')
                    #print(mass_final)
                    #print(spin_final)
                    #print(velocity_final)
                    #print(radius_final)
                    # Checking generation values to ensure that correct generation of remnant is allocated
                    if int(gen_1) == 1 or int(gen_2) == 1:
                        gen_final.append(gen_1 + gen_2)
                    else:
                        if int(gen_1) > int(gen_2):
                            gen_final.append(gen_1 + 1)
                        elif int(gen_2) > int(gen_1):
                            gen_final.append(gen_2 + 1)
                        else:
                            gen_final.append(gen_1 + 1)
                        
                    print("M_f = ", M_f)
                    print("spin_f = ", spin_f)
                    print("v_f = ", v_f)
                    print("Merger took ", run_time, " seconds")
        
        else:
            print('Galaxy ', gal[i], ' and run ', obj[j])
            print('binary found at galaxy ', gal[i], ' and binary ', obj[j])
            act_bin_prev = pd.read_csv(runs[i][j-1], delimiter=' ', header = 0)
            
            mass_1 = act_bin_prev['mass_1']
            mass_2 = act_bin_prev['mass_2']
            spin_1 = act_bin_prev['spin_1']
            spin_2 = act_bin_prev['spin_2']
            spin_angle_1 = act_bin_prev['spin_angle_1']
            spin_angle_2 = act_bin_prev['spin_angle_2']
            
            bh_prev = act_bin_prev['id_num'].values
            bh = active_bin['id_num'].values
            
            #This loop check to see if any binaries have formed
            for value in bh:
                if act_bin_prev.empty:
                    print('binary ', value, ' has formed')
                elif value not in bh_prev:
                    print('binary ', value, ' has formed')
                else:
                    print('binary ', value, ' has not yet mergered')
            
            for k, value in enumerate(bh_prev):
                if value not in bh:
                    print('binary ', value, ' has merged...beginning surrogate model')
                    #merger_counter_obj.append(obj[j])
                    mass_1 = act_bin_prev['mass_1'][k]
                    mass_2 = act_bin_prev['mass_2'][k]
                    spin_1_mag = act_bin_prev['spin_1'][k]
                    spin_2_mag = act_bin_prev['spin_2'][k]
                    spin_angle_1 = act_bin_prev['spin_angle_1'][k]
                    spin_angle_2 = act_bin_prev['spin_angle_2'][k]
                    radius = act_bin_prev['bin_orb_a'][k]
                    gen_1 = act_bin_prev['gen_1'][k]
                    gen_2 = act_bin_prev['gen_2'][k]
                    phi_12 = spin_angle_2 - spin_angle_1

                    # This should be in units of mass_1 + mass_2
                    bin_sep = 1000
                    bin_inc = [0, 0, 1]
                    bin_phase = 0
                    # These next three are used to correct the remnant velocity;
                    # If they are None, no correction is applied.
                    bin_orb_a = None
                    mass_SMBH = None
                    spin_SMBH = None

                    #print('surrogate test: ', mass_1, mass_2, spin_1_mag, spin_2_mag, spin_angle_1, spin_angle_2, phi_12)

                    surrogate = fit_modeler.GPRFitters.read_from_file(f"surrogate.joblib")

                    start = time.time()
                    M_f, spin_f, v_f = surrogate.evolve_binary(
                        mass_1,
                        mass_2,
                        spin_1_mag,
                        spin_2_mag,
                        spin_angle_1,
                        spin_angle_2,
                        phi_12,
                        bin_sep,
                        bin_inc,
                        bin_phase,
                        bin_orb_a,
                        mass_SMBH,
                        spin_SMBH,
                        surrogate,
                        verbose=True,
                    )
                    end = time.time()
                    
                    run_time = end - start

                    # These values are the surrogate outputs for each binary system that goes through a merger event
                    mass_final.append(M_f)
                    spin_final.append(spin_f)
                    velocity_final.append(v_f)
                    radius_final.append(radius)
                    bin_orb_a = act_bin_prev['bin_orb_a'][k]
                    boa_final.append(bin_orb_a)
                    
                    #print('x_final')
                    #print(mass_final)
                    #print(spin_final)
                    #print(velocity_final)
                    #print(radius_final)
                    
                    # Checking generation values to ensure that correct generation of remnant is allocated
                    if int(gen_1) == 1 or int(gen_2) == 1:
                        gen_final.append(gen_1 + gen_2)
                    else:
                        if int(gen_1) > int(gen_2):
                            gen_final.append(gen_1 + 1)
                        elif int(gen_2) > int(gen_1):
                            gen_final.append(gen_2 + 1)
                        else:
                            gen_final.append(gen_1 + 1)
                    
                    # ============= Need to incorporate starting mass to determine the initial mass compared to final mass after merger =============
                    #starting_mass1.append(mass_1)
                    #starting_mass2.append(mass_2)
                    #starting_spin1.append(spin_1)
                    #starting_spin2.append(spin_2)#
                        
                    print("M_f = ", M_f)
                    print("spin_f = ", spin_f)
                    print("v_f = ", v_f)
                    print("Merger took ", run_time, " seconds")
        #merger_counter_gal.append(merger_counter_obj)
                    
        #merger_counter_gal.append(merger_counter_obj)
        #print('galaxy ', gal[i], ' had mergers at timesteps ', merger_counter_gal)
        
        # Sorting all the merger event properties into a collective list that contains all merger event properties 
        total_mass_final.append(mass_final)
        total_spin_final.append(spin_final)
        total_velocity_final.append(velocity_final)
        total_radius_final.append(radius_final)
        total_gen_final.append(gen_final)
        total_boa_final.append(boa_final)
        
        #print('total_x_final')
        #print(len(total_mass_final))
        #print(len(total_spin_final))
        #print(len(total_velocity_final))
        #print(len(total_gen_final))
        #total_start_mass1.append(starting_mass1)
        #total_start_mass2.append(starting_mass2)
        #total_start_spin1.append(starting_spin1)
        #total_start_spin2.append(starting_spin2)

# print(total_mass_final)
# print(total_spin_final)len(
# print(total_velocity_final)
# print(total_radius_final)
# print('\n')
# print(total_start_mass1)
# print(total_start_mass2)
# print(total_start_spin1)
# print(total_start_spin2)

sur_time_end = time.time()
final_time = sur_time_end - sur_time_start
print('//////////////////////////////////////////                FINAL RUN TIME : ', int(final_time/60), 'min -', int(final_time % 60), 'sec                 //////////////////////////////////////////')

# Since there are many timesteps that do not have merger events, there is an empty list that is pulled for the merger
# The reduced properties removes the empty lists and creates a final list with no empty sections of data
reduced_mass_final = []
reduced_spin_final = []
reduced_velocity_final = []
reduced_radius_final = []
reduced_gen_final = []
reduced_boa_final = []

for i in range(len(total_mass_final)):
    if total_mass_final[i] != []:
        reduced_mass_final.append(total_mass_final[i])
for i in range(len(total_spin_final)):
    if total_spin_final[i] != []:
        reduced_spin_final.append(total_spin_final[i])
for i in range(len(total_velocity_final)):
    if total_velocity_final[i] != []:
        reduced_velocity_final.append(total_velocity_final[i])
for i in range(len(total_radius_final)):
    if total_radius_final[i] != []:
        reduced_radius_final.append(total_radius_final[i])
for i in range(len(total_gen_final)):
    if total_gen_final[i] != []:
        reduced_gen_final.append(total_gen_final[i])
for i in range(len(total_boa_final)):
    if total_boa_final[i] != []:
        reduced_boa_final.append(total_boa_final[i])

        
#print('reduced_x_final')
#print(reduced_mass_final)
#print(reduced_gen_final)
#print(len(reduced_spin_final))
#print(len(reduced_velocity_final))
#print(len(reduced_radius_final))
#print(len(reduced_radius_final))
# Now that we have reduced properties, that are arranged in multidimensional arrays, for each of the binaries, we need to put them into a single large binary 
# that allows us to be able to plot the values and get a visualization on how the data appears
plot_mass = []
for i in range(len(reduced_mass_final)):
    for j in range(len(reduced_mass_final[i])):
        plot_mass.append(reduced_mass_final[i][j])
# print(plot_mass)

plot_spin = []
for i in range(len(reduced_spin_final)):
    for j in range(len(reduced_spin_final[i])):
        plot_spin.append(reduced_spin_final[i][j])
# print(plot_spin)

plot_velocity = []
for i in range(len(reduced_velocity_final)):
    for j in range(len(reduced_velocity_final[i])):
        plot_velocity.append(reduced_velocity_final[i][j])
# print(plot_velocity)

plot_radius = []
for i in range(len(reduced_radius_final)):
    for j in range(len(reduced_radius_final[i])):
        plot_radius.append(reduced_radius_final[i][j])
# print(plot_radius)

plot_gen = []
for i in range(len(reduced_gen_final)):
    for j in range(len(reduced_gen_final[i])):
        plot_gen.append(reduced_gen_final[i][j])
#print(plot_gen)

plot_boa = []
for i in range(len(reduced_boa_final)):
    for j in range(len(reduced_boa_final[i])):
        plot_boa.append(reduced_boa_final[i][j])
#print(plot_boa)

#print('plot_x')
#print(len(plot_gen))
#print(len(plot_mass))
#print(len(plot_radius))
#print(len(plot_spin))
#print(len(plot_velocity))

# Converting spin_1 magnitude values into cartesian values
chi_mag = [[] for _ in range(len(plot_spin))] 

for i in range(len(chi_mag)):
    for j in range(len(plot_spin[i])):
        chi_mag[i] = np.sqrt(plot_spin[i][0]**2 + plot_spin[i][1]**2 + plot_spin[i][2]**2)
#print(len(chi_mag))

# Converting spin_1 magnitude values into cartesian values
vel_mag = [[] for _ in range(len(plot_velocity))] 

for i in range(len(vel_mag)):
    vel_mag[i] = np.linalg.norm(plot_velocity[i]) * const.c.value / 1000
# print(vel_mag)

#print(len(vel_mag))
# Out:
# ===================================   NEW GALAXY   =================================
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  1
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  2
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  3
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  4
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  5
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  6
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  7
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  8
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  9
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  10
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  11
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  12
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  13
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  14
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  15
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  16
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  17
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  18
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  19
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  20
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  21
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  22
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  23
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  24
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  25
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  26
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  27
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  28
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  29
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  30
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  31
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  32
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  33
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  34
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  35
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  36
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  37
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  38
# binary found at galaxy  000  and binary  38
# binary  205.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  39
# binary found at galaxy  000  and binary  39
# binary  205.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  40
# file is empty. Checking for previous binaries and moving onto next system
# binary  205.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  33.2397398947
# spin_f =  [ 0.00795633  0.00361803  0.69024016]
# v_f =  [  1.47488020e-04   2.08567933e-05  -1.68649845e-04]
# Merger took  0.15181303024291992  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  41
# binary found at galaxy  000  and binary  41
# binary  206.0  has formed
# binary  207.0  has formed
# binary  208.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  42
# binary found at galaxy  000  and binary  42
# binary  206.0  has not yet mergered
# binary  207.0  has not yet mergered
# binary  208.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  43
# binary found at galaxy  000  and binary  43
# binary  206.0  has not yet mergered
# binary  208.0  has not yet mergered
# binary  207.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  30.6111991246
# spin_f =  [ 0.02774401 -0.00821084  0.67110901]
# v_f =  [  5.52280500e-05  -7.02269661e-05   1.33972187e-05]
# Merger took  0.22838687896728516  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  44
# binary found at galaxy  000  and binary  44
# binary  206.0  has not yet mergered
# binary  208.0  has not yet mergered
# binary  210.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  45
# binary found at galaxy  000  and binary  45
# binary  208.0  has not yet mergered
# binary  211.0  has formed
# binary  212.0  has formed
# binary  213.0  has formed
# binary  206.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  54.152093257
# spin_f =  [ 0.00624389 -0.0148672   0.67228046]
# v_f =  [  3.71679027e-06   2.67692583e-04  -1.37807610e-04]
# Merger took  0.04909205436706543  seconds
# binary  210.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  21.0656027278
# spin_f =  [-0.00820142 -0.00923807  0.68084808]
# v_f =  [ -1.16318661e-04   5.15773118e-06   2.16270518e-04]
# Merger took  0.21642065048217773  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  46
# binary found at galaxy  000  and binary  46
# binary  211.0  has not yet mergered
# binary  212.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has formed
# binary  208.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  25.4420674705
# spin_f =  [-0.01111634  0.00265193  0.68381902]
# v_f =  [ -2.96007739e-04   8.99562866e-05  -5.58304768e-04]
# Merger took  0.11772584915161133  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  47
# binary found at galaxy  000  and binary  47
# binary  212.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has formed
# binary  216.0  has formed
# binary  211.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  26.5031497448
# spin_f =  [ 0.0034858  -0.0050334   0.69851011]
# v_f =  [ -2.49417421e-05  -2.09804671e-05   4.60117029e-05]
# Merger took  0.10754680633544922  seconds
# binary  213.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  30.793816493
# spin_f =  [ 0.00599639 -0.05742962  0.63019238]
# v_f =  [ -2.06718411e-04  -4.46333135e-04   6.57829765e-05]
# Merger took  0.08346700668334961  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  48
# binary found at galaxy  000  and binary  48
# binary  212.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  000  and run  49
# binary found at galaxy  000  and binary  49
# binary  212.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# ===================================   NEW GALAXY   =================================
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  1
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  2
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  3
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  4
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  5
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  6
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  7
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  8
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  9
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  10
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  11
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  12
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  13
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  14
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  15
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  16
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  17
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  18
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  19
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  20
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  21
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  22
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  23
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  24
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  25
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  26
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  27
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  28
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  29
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  30
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  31
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  32
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  33
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  34
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  35
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  36
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  37
# binary found at galaxy  001  and binary  37
# binary  205.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  38
# file is empty. Checking for previous binaries and moving onto next system
# binary  205.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  44.0898798809
# spin_f =  [ 0.00521516  0.00295199  0.71255133]
# v_f =  [  2.90870586e-05   7.42421788e-05  -6.66714166e-05]
# Merger took  0.051441192626953125  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  39
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  40
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  41
# binary found at galaxy  001  and binary  41
# binary  206.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  42
# binary found at galaxy  001  and binary  42
# binary  206.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  43
# file is empty. Checking for previous binaries and moving onto next system
# binary  206.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  26.2932352242
# spin_f =  [-0.00520542  0.00679965  0.64996431]
# v_f =  [ -4.04008473e-04  -4.97298607e-05  -1.42721564e-04]
# Merger took  0.12231898307800293  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  44
# binary found at galaxy  001  and binary  44
# binary  208.0  has formed
# binary  209.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  45
# binary found at galaxy  001  and binary  45
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  46
# binary found at galaxy  001  and binary  46
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  210.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  47
# binary found at galaxy  001  and binary  47
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  210.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  29.7292207346
# spin_f =  [-0.0212655  -0.01071794  0.67678668]
# v_f =  [  6.87955691e-05   3.83388650e-06   3.66301226e-04]
# Merger took  0.08909296989440918  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  48
# binary found at galaxy  001  and binary  48
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  213.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  001  and run  49
# binary found at galaxy  001  and binary  49
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has formed
# binary  215.0  has formed
# binary  216.0  has formed
# binary  217.0  has formed
# ===================================   NEW GALAXY   =================================
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  1
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  2
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  3
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  4
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  5
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  6
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  7
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  8
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  9
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  10
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  11
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  12
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  13
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  14
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  15
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  16
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  17
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  18
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  19
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  20
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  21
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  22
# binary found at galaxy  002  and binary  22
# binary  204.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  23
# binary found at galaxy  002  and binary  23
# binary  204.0  has not yet mergered
# binary  205.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  24
# binary found at galaxy  002  and binary  24
# binary  204.0  has not yet mergered
# binary  205.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  30.3642474816
# spin_f =  [ 0.01818097 -0.01851748  0.68444366]
# v_f =  [-0.00018771 -0.00027331  0.00031979]
# Merger took  0.09270501136779785  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  25
# binary found at galaxy  002  and binary  25
# binary  204.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  26
# binary found at galaxy  002  and binary  26
# binary  204.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  27
# binary found at galaxy  002  and binary  27
# binary  204.0  has not yet mergered
# binary  208.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  28
# binary found at galaxy  002  and binary  28
# binary  204.0  has not yet mergered
# binary  208.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  29
# binary found at galaxy  002  and binary  29
# binary  204.0  has not yet mergered
# binary  208.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  30
# binary found at galaxy  002  and binary  30
# binary  204.0  has not yet mergered
# binary  211.0  has formed
# binary  208.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  47.141444173
# spin_f =  [ 0.03154118  0.01088761  0.59840348]
# v_f =  [ 0.00050501  0.00023249  0.0002779 ]
# Merger took  0.052718162536621094  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  31
# binary found at galaxy  002  and binary  31
# binary  204.0  has not yet mergered
# binary  211.0  has not yet mergered
# binary  212.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  32
# binary found at galaxy  002  and binary  32
# binary  204.0  has not yet mergered
# binary  212.0  has not yet mergered
# binary  211.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  45.5046299834
# spin_f =  [ 0.01452281 -0.00083623  0.58932756]
# v_f =  [ 0.00057209 -0.00010088  0.00033141]
# Merger took  0.05271410942077637  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  33
# binary found at galaxy  002  and binary  33
# binary  212.0  has not yet mergered
# binary  204.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  48.9467992168
# spin_f =  [-0.05356188 -0.11001581  0.55897501]
# v_f =  [-0.00043467 -0.00032208  0.00061486]
# Merger took  0.0616610050201416  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  34
# binary found at galaxy  002  and binary  34
# binary  212.0  has not yet mergered
# binary  218.0  has formed
# binary  219.0  has formed
# binary  220.0  has formed
# binary  221.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  35
# binary found at galaxy  002  and binary  35
# binary  212.0  has not yet mergered
# binary  219.0  has not yet mergered
# binary  220.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  218.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  23.3168353234
# spin_f =  [ 0.01161127 -0.01327032  0.67477358]
# v_f =  [ -1.69970836e-05  -3.39673137e-05  -7.44282690e-05]
# Merger took  0.14606308937072754  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  36
# binary found at galaxy  002  and binary  36
# binary  212.0  has not yet mergered
# binary  219.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  222.0  has formed
# binary  220.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  47.6151689331
# spin_f =  [ 0.00351304  0.00290633  0.57307936]
# v_f =  [ -6.22519983e-04  -3.87847688e-05  -4.29196482e-05]
# Merger took  0.05548691749572754  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  37
# binary found at galaxy  002  and binary  37
# binary  219.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  222.0  has not yet mergered
# binary  212.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  27.358820226
# spin_f =  [ -1.81685830e-03  -1.29046354e-04   6.49346320e-01]
# v_f =  [ -2.18189082e-04   3.83925471e-04  -8.61675225e-05]
# Merger took  0.4549551010131836  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  38
# binary found at galaxy  002  and binary  38
# binary  221.0  has not yet mergered
# binary  222.0  has not yet mergered
# binary  223.0  has formed
# binary  224.0  has formed
# binary  225.0  has formed
# binary  219.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  41.6934214545
# spin_f =  [ 0.02255066 -0.02234376  0.62620042]
# v_f =  [ -4.83055761e-04  -1.88824105e-05   8.92382063e-05]
# Merger took  0.05985689163208008  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  39
# binary found at galaxy  002  and binary  39
# binary  221.0  has not yet mergered
# binary  222.0  has not yet mergered
# binary  223.0  has not yet mergered
# binary  224.0  has not yet mergered
# binary  225.0  has not yet mergered
# binary  226.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  40
# binary found at galaxy  002  and binary  40
# binary  221.0  has not yet mergered
# binary  222.0  has not yet mergered
# binary  224.0  has not yet mergered
# binary  225.0  has not yet mergered
# binary  226.0  has not yet mergered
# binary  227.0  has formed
# binary  228.0  has formed
# binary  223.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  34.0122411136
# spin_f =  [-0.01777302  0.01925456  0.56174295]
# v_f =  [ 0.00056848  0.00030433 -0.00023691]
# Merger took  0.07794308662414551  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  41
# binary found at galaxy  002  and binary  41
# binary  222.0  has not yet mergered
# binary  224.0  has not yet mergered
# binary  226.0  has not yet mergered
# binary  227.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  229.0  has formed
# binary  221.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  23.8804180611
# spin_f =  [-0.0071546   0.00529251  0.68444835]
# v_f =  [ -4.86116522e-05   8.79846785e-05   6.00723819e-04]
# Merger took  0.12148094177246094  seconds
# binary  225.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  27.2062008377
# spin_f =  [-0.00584099 -0.01984532  0.68092046]
# v_f =  [-0.0003598  -0.0002121  -0.00015526]
# Merger took  0.10251116752624512  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  42
# binary found at galaxy  002  and binary  42
# binary  222.0  has not yet mergered
# binary  224.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  229.0  has not yet mergered
# binary  226.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  65.9276358862
# spin_f =  [ 0.14700092 -0.13448328  0.65770073]
# v_f =  [ 0.00043679 -0.00077872  0.00093859]
# Merger took  0.0379939079284668  seconds
# binary  227.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  29.9828485474
# spin_f =  [  1.29225596e-03   4.21479689e-04   6.26437827e-01]
# v_f =  [  4.63224109e-04  -3.82426005e-05   2.85337473e-06]
# Merger took  0.09089303016662598  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  43
# binary found at galaxy  002  and binary  43
# binary  222.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  229.0  has not yet mergered
# binary  224.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  39.9636761496
# spin_f =  [-0.00961787 -0.02853248  0.61848247]
# v_f =  [ 0.00042077 -0.00030154  0.00025548]
# Merger took  0.06343293190002441  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  44
# binary found at galaxy  002  and binary  44
# binary  222.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  231.0  has formed
# binary  229.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  53.1699242528
# spin_f =  [ 0.01325582  0.01592534  0.69276129]
# v_f =  [  2.46121597e-04  -2.74082104e-04   5.84121003e-05]
# Merger took  0.046098947525024414  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  45
# binary found at galaxy  002  and binary  45
# binary  222.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  231.0  has not yet mergered
# binary  232.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  46
# binary found at galaxy  002  and binary  46
# binary  222.0  has not yet mergered
# binary  228.0  has not yet mergered
# binary  231.0  has not yet mergered
# binary  232.0  has not yet mergered
# binary  233.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  47
# binary found at galaxy  002  and binary  47
# binary  222.0  has not yet mergered
# binary  232.0  has not yet mergered
# binary  233.0  has not yet mergered
# binary  234.0  has formed
# binary  228.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  56.5404425351
# spin_f =  [-0.02223395  0.02269977  0.66051682]
# v_f =  [-0.00024636  0.0002811  -0.00035759]
# Merger took  0.04594993591308594  seconds
# binary  231.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  40.9465219163
# spin_f =  [-0.28049294  0.31297364  0.67206525]
# v_f =  [-0.00088922  0.00143785  0.0024311 ]
# Merger took  0.06704187393188477  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  48
# binary found at galaxy  002  and binary  48
# binary  222.0  has not yet mergered
# binary  233.0  has not yet mergered
# binary  234.0  has not yet mergered
# binary  235.0  has formed
# binary  232.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  85.3175818157
# spin_f =  [ 0.71113324  0.00666035  0.3474383 ]
# v_f =  [ 0.00186669 -0.00033394  0.00049531]
# Merger took  0.037129878997802734  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  002  and run  49
# binary found at galaxy  002  and binary  49
# binary  222.0  has not yet mergered
# binary  233.0  has not yet mergered
# binary  234.0  has not yet mergered
# binary  235.0  has not yet mergered
# binary  236.0  has formed
# ===================================   NEW GALAXY   =================================
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  1
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  2
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  3
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  4
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  5
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  6
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  7
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  8
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  9
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  10
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  11
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  12
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  13
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  14
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  15
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  16
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  17
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  18
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  19
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  20
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  21
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  22
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  23
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  24
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  25
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  26
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  27
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  28
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  29
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  30
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  31
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  32
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  33
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  34
# file is empty. Checking for previous binaries and moving onto next system
# no previously merged binaries
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  35
# binary found at galaxy  003  and binary  35
# binary  205.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  36
# binary found at galaxy  003  and binary  36
# binary  205.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  37
# binary found at galaxy  003  and binary  37
# binary  205.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  38
# binary found at galaxy  003  and binary  38
# binary  205.0  has not yet mergered
# binary  206.0  has formed
# binary  207.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  39
# binary found at galaxy  003  and binary  39
# binary  205.0  has not yet mergered
# binary  207.0  has not yet mergered
# binary  208.0  has formed
# binary  206.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  28.8080889529
# spin_f =  [-0.01055669 -0.02585561  0.59893302]
# v_f =  [ -1.07798656e-05  -6.07418664e-04   2.69959570e-04]
# Merger took  0.10252690315246582  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  40
# binary found at galaxy  003  and binary  40
# binary  205.0  has not yet mergered
# binary  207.0  has not yet mergered
# binary  208.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  41
# binary found at galaxy  003  and binary  41
# binary  205.0  has not yet mergered
# binary  207.0  has not yet mergered
# binary  208.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  21.4369385664
# spin_f =  [ 0.00302378  0.00962597  0.69406934]
# v_f =  [ -7.86409930e-05   6.40211805e-05   2.44585815e-04]
# Merger took  0.15035080909729004  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  003  and run  42
# binary found at galaxy  003  and binary  42
# binary  207.0  has not yet mergered
# binary  210.0  has formed
# binary  211.0  has formed
# ...
# binary  205.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  28
# binary found at galaxy  099  and binary  28
# binary  205.0  has not yet mergered
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  29
# file is empty. Checking for previous binaries and moving onto next system
# binary  205.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  24.2518467447
# spin_f =  [ 0.00088852  0.00171705  0.68997171]
# v_f =  [ -6.51042292e-05   5.16517939e-06   1.77780488e-05]
# Merger took  0.11602401733398438  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  30
# binary found at galaxy  099  and binary  30
# binary  206.0  has formed
# binary  207.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  31
# binary found at galaxy  099  and binary  31
# binary  206.0  has not yet mergered
# binary  207.0  has not yet mergered
# binary  208.0  has formed
# binary  209.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  32
# binary found at galaxy  099  and binary  32
# binary  206.0  has not yet mergered
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  211.0  has formed
# binary  207.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  20.7402395217
# spin_f =  [ 0.00627448  0.02045138  0.70667861]
# v_f =  [  2.66169420e-05   1.23173976e-04   1.11664856e-03]
# Merger took  0.27135515213012695  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  33
# binary found at galaxy  099  and binary  33
# binary  206.0  has not yet mergered
# binary  208.0  has not yet mergered
# binary  209.0  has not yet mergered
# binary  211.0  has not yet mergered
# binary  212.0  has formed
# binary  213.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  34
# binary found at galaxy  099  and binary  34
# binary  211.0  has not yet mergered
# binary  212.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has formed
# binary  215.0  has formed
# binary  216.0  has formed
# binary  206.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  31.1928854442
# spin_f =  [-0.0058761  -0.01685113  0.66944101]
# v_f =  [-0.00018076 -0.00013214  0.00082796]
# Merger took  0.08183813095092773  seconds
# binary  208.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  23.7042784133
# spin_f =  [-0.00422876 -0.00768942  0.69530969]
# v_f =  [  6.23175876e-06  -1.91543417e-04  -1.90777999e-04]
# Merger took  0.12400221824645996  seconds
# binary  209.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  23.506848237
# spin_f =  [ 0.00405342  0.00679242  0.6445928 ]
# v_f =  [ 0.00022585 -0.00018121 -0.00085244]
# Merger took  0.1322939395904541  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  35
# binary found at galaxy  099  and binary  35
# binary  211.0  has not yet mergered
# binary  212.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  217.0  has formed
# binary  218.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  36
# binary found at galaxy  099  and binary  36
# binary  211.0  has not yet mergered
# binary  212.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  217.0  has not yet mergered
# binary  218.0  has not yet mergered
# binary  219.0  has formed
# binary  220.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  37
# binary found at galaxy  099  and binary  37
# binary  211.0  has not yet mergered
# binary  213.0  has not yet mergered
# binary  214.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  219.0  has not yet mergered
# binary  220.0  has not yet mergered
# binary  221.0  has formed
# binary  212.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  30.357191604
# spin_f =  [-0.02443241  0.00359235  0.67970112]
# v_f =  [  4.03987810e-06  -6.50762105e-05   1.54496328e-04]
# Merger took  0.07962584495544434  seconds
# binary  217.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  46.6729617562
# spin_f =  [-0.03659517  0.0931095   0.59615499]
# v_f =  [-0.00041783  0.00114258  0.00170191]
# Merger took  0.058846235275268555  seconds
# binary  218.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  20.7768015304
# spin_f =  [ 0.02151931  0.00548709  0.67409511]
# v_f =  [ 0.00029551 -0.00020545 -0.00073569]
# Merger took  0.16835808753967285  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  38
# binary found at galaxy  099  and binary  38
# binary  211.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  222.0  has formed
# binary  213.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  40.4127638768
# spin_f =  [-0.0115096  -0.00530236  0.59998629]
# v_f =  [ 0.00049707  0.00032382 -0.00010898]
# Merger took  0.06247901916503906  seconds
# binary  214.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  45.0116411403
# spin_f =  [-0.00147702  0.00238876  0.46895869]
# v_f =  [ 0.00046546 -0.00040519  0.00017331]
# Merger took  0.05902814865112305  seconds
# binary  219.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  29.1519193691
# spin_f =  [-0.00908922  0.00798735  0.6873134 ]
# v_f =  [ 0.00024388 -0.00012305  0.00030614]
# Merger took  0.08711409568786621  seconds
# binary  220.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  26.2372273054
# spin_f =  [ 0.01000691 -0.00164086  0.64348202]
# v_f =  [ -2.55105448e-04  -3.19816538e-04  -6.95478917e-06]
# Merger took  0.10568904876708984  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  39
# binary found at galaxy  099  and binary  39
# binary  211.0  has not yet mergered
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  223.0  has formed
# binary  222.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  47.6058716597
# spin_f =  [  1.26134120e-04   1.25133963e-03   6.32473927e-01]
# v_f =  [ -4.16030700e-04  -2.58220404e-04  -1.83546574e-05]
# Merger took  0.04649209976196289  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  40
# binary found at galaxy  099  and binary  40
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  211.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  28.1708830798
# spin_f =  [-0.00667974  0.0610524   0.68651011]
# v_f =  [-0.00019109 -0.00021897  0.00021935]
# Merger took  0.10316705703735352  seconds
# binary  223.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  26.329891275
# spin_f =  [-0.02339637 -0.01402232  0.65689594]
# v_f =  [-0.0002394   0.00036405  0.00098345]
# Merger took  0.11367034912109375  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  41
# binary found at galaxy  099  and binary  41
# binary  215.0  has not yet mergered
# binary  216.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  224.0  has formed
# binary  225.0  has formed
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  42
# binary found at galaxy  099  and binary  42
# binary  216.0  has not yet mergered
# binary  221.0  has not yet mergered
# binary  224.0  has not yet mergered
# binary  225.0  has not yet mergered
# binary  215.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  47.8574645179
# spin_f =  [-0.03755503  0.02293256  0.54601971]
# v_f =  [-0.00026562  0.00040438 -0.00012597]
# Merger took  0.055673837661743164  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  43
# binary found at galaxy  099  and binary  43
# binary  224.0  has not yet mergered
# binary  225.0  has not yet mergered
# binary  229.0  has formed
# binary  216.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  28.210683588
# spin_f =  [-0.00227874 -0.00434209  0.66961968]
# v_f =  [ -1.07329264e-04   4.02110512e-04  -3.94498629e-05]
# Merger took  0.2950589656829834  seconds
# binary  221.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  25.1699330492
# spin_f =  [ 0.03093438 -0.05874705  0.62642378]
# v_f =  [-0.0002442  -0.00040058 -0.00014776]
# Merger took  0.11655497550964355  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  44
# binary found at galaxy  099  and binary  44
# binary  225.0  has not yet mergered
# binary  229.0  has not yet mergered
# binary  224.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  34.5731421676
# spin_f =  [-0.06340146 -0.02994201  0.66999663]
# v_f =  [-0.00069528 -0.0001571  -0.00139177]
# Merger took  0.08238482475280762  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  45
# binary found at galaxy  099  and binary  45
# binary  225.0  has not yet mergered
# binary  230.0  has formed
# binary  231.0  has formed
# binary  229.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  35.1964013001
# spin_f =  [ 0.43169969 -0.16246119  0.50481185]
# v_f =  [ 0.00123896 -0.00085479  0.00031883]
# Merger took  0.08926892280578613  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  46
# binary found at galaxy  099  and binary  46
# binary  225.0  has not yet mergered
# binary  232.0  has formed
# binary  230.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  44.3799838185
# spin_f =  [-0.10357909 -0.11902936  0.61848648]
# v_f =  [-0.00137243  0.00050735  0.00437553]
# Merger took  0.06360507011413574  seconds
# binary  231.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  40.0176187573
# spin_f =  [ 0.11812099  0.63659698  0.41146449]
# v_f =  [ 0.00039395  0.00342327  0.00159876]
# Merger took  0.07278990745544434  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  47
# binary found at galaxy  099  and binary  47
# binary  232.0  has not yet mergered
# binary  233.0  has formed
# binary  234.0  has formed
# binary  225.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  29.7047694088
# spin_f =  [-0.23142527 -0.08388036  0.63203546]
# v_f =  [-0.0007644  -0.0006158   0.00323712]
# Merger took  0.10322403907775879  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  48
# binary found at galaxy  099  and binary  48
# binary  234.0  has not yet mergered
# binary  235.0  has formed
# binary  232.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  44.2001843112
# spin_f =  [ 0.27230845  0.03380372  0.74222781]
# v_f =  [ 0.00178463 -0.00023231  0.0048967 ]
# Merger took  0.1263718605041504  seconds
# binary  233.0  has merged...beginning surrogate model
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  62.0759881063
# spin_f =  [-0.11430012  0.28515683  0.5722053 ]
# v_f =  [ 0.00044819 -0.00231039 -0.00303039]
# Merger took  0.04593706130981445  seconds
# ----------------     NEW TIMESTEP     ----------------
# Galaxy  099  and run  49
# binary found at galaxy  099  and binary  49
# binary  235.0  has not yet mergered
# binary  236.0  has formed
# binary  237.0  has formed
# binary  234.0  has merged...beginning surrogate model
# mass_1 < mass_2! Flipping black hole labels.
# Evolving binary...
# Evolving binary to merger using PN equations...
# Evolving binary through merger with surrogate...
# M_f =  74.3729765802
# spin_f =  [ 0.07891739 -0.04731136  0.67954644]
# v_f =  [ -6.91883017e-05   3.83463946e-04  -2.96219941e-03]
# Merger took  0.03302717208862305  seconds
# //////////////////////////////////////////                FINAL RUN TIME :  5 min - 20 sec                 //////////////////////////////////////////
# ┌ Warning:
# │ This system is likely to encounter the up-down instability in the frequency
# │ range (Ω₊, Ω₋)=(0.0016262090316004221, 0.037094042256639044), which corresponds to
# │ PN velocity parameters (v₊, v₋)=(0.35260684226871847, 1.0).
# │ This is a true physical instability, not just a numerical issue.  Despite the
# │ fact that the initial conditions contain very small precession, the system will
# │ likely evolve to have very large precession.  See `up_down_instability` docs
# │ for details.
# │
# │ Parameters:
# │   M₁ = 13.613073274478927
# │   M₂ = 13.345433783915908
# │   χ⃗₁ =  + 0.008820082106741197𝐢 - 0.0004850417595920164𝐣 + 0.09155760400956883𝐤
# │   χ⃗₂ =  - 0.0017525752248629188𝐢 + (9.637916751763263e-5)𝐣 - 0.011526282846303724𝐤
# │   R = rotor(1.0 + 0.0𝐢 + 0.0𝐣 + 0.0𝐤)
# │   v = 0.1622653324407844
# │   v₁ = 0.0
# │   vₑ = 1.0
# └ @ PostNewtonian ~/.julia/packages/PostNewtonian/Ntoxm/src/dynamics/up_down_instability.jl:69

# %%
from mcfacts.vis import data
from mcfacts.vis import plotting
from mcfacts.vis import styles
import matplotlib.ticker as mticker

# Use the McFACTS plot style
plt.style.use("mcfacts.vis.mcfacts_figures")

figsize = "apj_col"

# %%
g1_mask = (gen_1 == 1) & (gen_2 == 1)
g2_mask = ((gen_1 == 2) | (gen_2 == 2)) & ((gen_1 <= 2) & (gen_2 <= 2))
gX_mask = (gen_1 >= 3) | (gen_2 >= 3)

# %%
g1_plot_mass = []
g2_plot_mass = []
gx_plot_mass = []

for i in range(len(plot_gen)):
    if plot_gen[i] == 2.:
        g1_plot_mass.append(plot_mass[i])
    elif plot_gen[i] == 3.:
        g2_plot_mass.append(plot_mass[i])
    elif plot_gen[i] > 3.:
        gx_plot_mass.append(plot_mass[i])

# %%
fig = plt.figure(figsize=plotting.set_size(figsize))
#counts, bins = np.histogram(mergers[:, 2])
# plt.hist(bins[:-1], bins, weights=counts)
bins = np.arange(int(np.min(plot_mass)), int(np.max(plot_mass)) + 2, 1)

hist_data = [g1_plot_mass, g2_plot_mass, gx_plot_mass]
hist_label = ['1g-1g', '2g-1g or 2g-2g', r'$\geq$3g-Ng']
hist_color = [styles.color_gen1, styles.color_gen2, styles.color_genX]

plt.hist(hist_data, bins=bins, align='left', color=hist_color, alpha=0.9, rwidth=0.8, label=hist_label, stacked=True)

plt.ylabel('Number of Mergers')
plt.xlabel(r'Remnant Mass [$M_\odot$]')
#plt.xscale('log')
svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
svf_ax.tick_params(axis='x', direction='out', which='both')
#plt.grid(True, color='gray', ls='dashed')
svf_ax.yaxis.grid(True, color='gray', ls='dashed')

plt.xticks(np.geomspace(int(np.min(plot_mass)), int(np.max(plot_mass)), 5).astype(int))
#plt.xticks(np.geomspace(20, 200, 5).astype(int))

svf_ax.xaxis.set_major_formatter(mticker.StrMethodFormatter('{x:.0f}'))
svf_ax.xaxis.set_minor_formatter(mticker.NullFormatter())

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

# %%
g1_plot_boa = []
g2_plot_boa = []
gx_plot_boa = []

for i in range(len(plot_gen)):
    if plot_gen[i] == 2.:
        g1_plot_boa.append(plot_boa[i])
    elif plot_gen[i] == 3.:
        g2_plot_boa.append(plot_boa[i])
    elif plot_gen[i] > 3.:
        gx_plot_boa.append(plot_boa[i])

# %%
trap_radius = 700

# plt.title('Migration Trap influence')
for i in range(len(plot_boa)):
    if plot_boa[i] < 10.0:
        plot_boa[i] = 10.0

# Separate generational subpopulations
gen1_orb_a = g1_plot_boa
gen2_orb_a = g2_plot_boa
genX_orb_a = gx_plot_boa
gen1_mass = g1_plot_mass
gen2_mass = g2_plot_mass
genX_mass = gx_plot_mass
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_orb_a, gen1_mass,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_orb_a, gen2_mass,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_orb_a, genX_mass,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axvline(trap_radius, color='k', linestyle='--', zorder=0,
            label=f'Trap Radius = {trap_radius} ' + r'$R_g$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.ylabel(r'Remnant Mass [$M_\odot$]')
plt.xlabel(r'Radius [$R_g$]')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
g1_plot_kick = []
g2_plot_kick = []
gx_plot_kick = []

for i in range(len(plot_gen)):
    if plot_gen[i] == 2.:
        g1_plot_kick.append(vel_mag[i])
    elif plot_gen[i] == 3.:
        g2_plot_kick.append(vel_mag[i])
    elif plot_gen[i] > 3.:
        gx_plot_kick.append(vel_mag[i])

# %%
v_kick = 200

# Separate generational subpopulations
gen1_mass = g1_plot_mass
gen2_mass = g2_plot_mass
genX_mass = gx_plot_mass
gen1_kick = g1_plot_kick
gen2_kick = g2_plot_kick
genX_kick = gx_plot_kick
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_mass, gen1_kick,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_mass, gen2_kick,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_mass, genX_kick,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axhline(v_kick, color='k', linestyle='--', zorder=0,
            label=f'Analytical Kick Velocity = {v_kick} ' + r'$[km/s]$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Remnant Mass [$M_\odot$]')
plt.ylabel(r'Kick Velocity [$km/s$]')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
g1_plot_spin = []
g2_plot_spin = []
gx_plot_spin = []

for i in range(len(plot_gen)):
    if plot_gen[i] == 2.:
        g1_plot_spin.append(chi_mag[i])
    elif plot_gen[i] == 3.:
        g2_plot_spin.append(chi_mag[i])
    elif plot_gen[i] > 3.:
        gx_plot_spin.append(chi_mag[i])

# %%
# Separate generational subpopulations
gen1_mass = g1_plot_mass
gen2_mass = g2_plot_mass
genX_mass = gx_plot_mass
gen1_spin = g1_plot_spin
gen2_spin = g2_plot_spin
genX_spin = gx_plot_spin
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_mass, gen1_spin,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_mass, gen2_spin,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_mass, genX_spin,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Remnant Mass [$M_\odot$]')
plt.ylabel(r'Spin')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
trap_radius = 700

'''# plt.title('Migration Trap influence')
for i in range(len(plot_boa)):
    if plot_boa[i] < 10.0:
        plot_boa[i] = 10.0'''

# Separate generational subpopulations
gen1_boa = g1_plot_boa
gen2_boa = g2_plot_boa
genX_boa = gx_plot_boa
gen1_kick = g1_plot_kick
gen2_kick = g2_plot_kick
genX_kick = gx_plot_kick
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_boa, gen1_kick,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_boa, gen2_kick,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_boa, genX_kick,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axhline(v_kick, color='k', linestyle='--', zorder=0,
            label=f'Analytical Kick Velocity = {v_kick} ' + r'$[km/s]$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Radius from SMBH [$R_g$]')
plt.ylabel(r'Kick velocity [$km/s$]')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
trap_radius = 700

'''# plt.title('Migration Trap influence')
for i in range(len(plot_boa)):
    if plot_boa[i] < 10.0:
        plot_boa[i] = 10.0'''

# Separate generational subpopulations
gen1_boa = g1_plot_boa
gen2_boa = g2_plot_boa
genX_boa = gx_plot_boa
gen1_spin = g1_plot_spin
gen2_spin = g2_plot_spin
genX_spin = gx_plot_spin
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_boa, gen1_spin,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_boa, gen2_spin,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_boa, genX_spin,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axvline(trap_radius, color='k', linestyle='--', zorder=0,
            label=f'Trap Radius = {trap_radius} ' + r'$R_g$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Radius from SMBH [$R_g$]')
plt.ylabel(r'Spin')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
trap_radius = 700

'''# plt.title('Migration Trap influence')
for i in range(len(plot_boa)):
    if plot_boa[i] < 10.0:
        plot_boa[i] = 10.0'''

# Separate generational subpopulations
gen1_boa = g1_plot_boa
gen2_boa = g2_plot_boa
genX_boa = gx_plot_boa
gen1_mass = g1_plot_mass
gen2_mass = g2_plot_mass
genX_mass = gx_plot_mass
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_boa, gen1_mass,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_boa, gen2_mass,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_boa, genX_mass,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axvline(trap_radius, color='k', linestyle='--', zorder=0,
            label=f'Trap Radius = {trap_radius} ' + r'$R_g$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Radius from SMBH [$R_g$]')
plt.ylabel(r'Remnant Mass [$M_\odot$]')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
trap_radius = 700

'''# plt.title('Migration Trap influence')
for i in range(len(plot_boa)):
    if plot_boa[i] < 10.0:
        plot_boa[i] = 10.0'''

# Separate generational subpopulations
gen1_kick = g1_plot_kick
gen2_kick = g2_plot_kick
genX_kick = gx_plot_kick
gen1_spin = g1_plot_spin
gen2_spin = g2_plot_spin
genX_spin = gx_plot_spin
fig = plt.figure(figsize=plotting.set_size(figsize))
plt.scatter(gen1_kick, gen1_spin,
            s=styles.markersize_gen1,
            marker=styles.marker_gen1,
            edgecolor=styles.color_gen1,
            facecolors="none",
            alpha=styles.markeralpha_gen1,
            label='1g-1g'
            )

plt.scatter(gen2_kick, gen2_spin,
            s=styles.markersize_gen2,
            marker=styles.marker_gen2,
            edgecolor=styles.color_gen2,
            facecolors="none",
            alpha=styles.markeralpha_gen2,
            label='2g-1g or 2g-2g'
            )

plt.scatter(genX_kick, genX_spin,
            s=styles.markersize_genX,
            marker=styles.marker_genX,
            edgecolor=styles.color_genX,
            facecolors="none",
            alpha=styles.markeralpha_genX,
            label=r'$\geq$3g-Ng'
            )

plt.axvline(v_kick, color='k', linestyle='--', zorder=0,
            label=f'Analytical Kick Velocity = {v_kick} ' + r'$[km/s]$')

# plt.text(650, 602, 'Migration Trap', rotation='vertical', size=18, fontweight='bold')
plt.xlabel(r'Kick velocity [$km/s$]')
plt.ylabel(r'Spin')
plt.xscale('log')
plt.yscale('log')

if figsize == 'apj_col':
    plt.legend(fontsize=6)
elif figsize == 'apj_page':
    plt.legend()

#plt.ylim(18, 1000)

svf_ax = plt.gca()
svf_ax.set_axisbelow(True)
plt.grid(True, color='gray', ls='dashed')

# %%
plt.hist(plot_mass, num_mergers)
plt.xlabel('Remnant ' r'Mass ($M_{\odot}$)')
plt.ylabel('Number of mergers')
plt.xlim([np.min(plot_mass) - 10, np.max(plot_mass)+10])
plt.title('Number of Mergers per Merger Mass')
plt.show()

# %%
plt.scatter(plot_mass, vel_mag)
plt.xlabel('Remnant ' r'Mass ($M_{\odot}$)')
plt.ylabel('Kick velocity (%c)')
plt.title('Merger Velocities per Merger Mass')
plt.show()

# %%
plt.scatter(plot_mass, chi_mag)
plt.xlabel('Remnant ' r'Mass ($M_{\odot}$)')
plt.ylabel('Spin')
plt.title('Spin per Merger Mass')
plt.show()

# %%
plt.scatter(plot_radius, vel_mag)
plt.xlabel('Radius ' r'($R_g$)')
plt.ylabel('Kick velocity (%c)')
plt.title('Kick Velocity at radius from SMBH ('r'$R_g$'')')
plt.show()

# %%
plt.scatter(plot_radius, chi_mag)
plt.xlabel('Radius ' r'($R_g$)')
plt.ylabel('Spin')
plt.title('Spin across at radius from SMBH ('r'$R_g$'')')
plt.show()

# %%
plt.scatter(plot_radius, plot_mass)
plt.xlabel('Radius ' r'($R_g$)')
plt.ylabel('Remnant ' r'Mass ($M_{\odot}$)')
plt.title('Merger mass at radius from SMBH ('r'$R_g$'')')
plt.show()
